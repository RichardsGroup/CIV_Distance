# %% [markdown]
# ### Errors in CIV distance.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np
import richardsplot as rplot
from sklearn.preprocessing import scale
import joblib

import sys
#sys.path.append("/Users/trevormccaffrey/Desktop/git/CIV_Distance/")
sys.path.append("/Volumes/Macintosh HD 1/Users/trevormccaffrey/Desktop/git/CIV_Distance/")
from CIVfunctions import project, CIV_distance

# %% [markdown]
# ---
#
# #### Basic implementation
#
# Load in example file with CIV EW+Blueshift already computed.

# %%
# !ls ..
# Out:
# CIV_distance_example.html data                      imgs
# CIVfunctions.py           errors                    scalers
# README.md                 example.ipynb
# __pycache__               example_plots.ipynb

# %%
dat = pd.read_csv("../data/CIVdata_full.csv")
good  = dat["good"].values; dat = dat[good].iloc[:,1:]
dat.head()
# Out:
#       CIV_blue     CIV_EW  CIV_Distance
# 0  -494.607254  51.555290      0.446845
# 2  1458.723050  28.998439      0.695980
# 3   573.970534  30.974248      0.595771
# 4   992.493501  91.379252      0.323098
# 6   728.106112  31.517845      0.608577

# %%
dat.shape
# Out:
# (140986, 3)

# %%
ew    = dat["CIV_EW"].values
logEW = np.log10(ew)
blue  = dat["CIV_blue"].values
dist  = dat["CIV_Distance"].values

#Best-fit line -- this part could be improved
bestfit = np.load("../data/bestfit.npy")

# %%
CIV_distance??

# %%
fig = plt.figure(figsize=(9,9))

#Visualize increasing CIV distance
style = "Simple, tail_width=1.25, head_width=20, head_length=20"
kw = dict(arrowstyle=style, color="k")
a1 = patches.FancyArrowPatch((3000, 2.1), (4900, 1.7),
                             connectionstyle="arc3,rad=.35", **kw)
plt.gca().add_patch(a1)
plt.text(x=3440,y=2.22,s="Increasing", fontsize=30, weight='extra bold')
plt.text(x=3400,y=2.13,s="C$_\mathrm{IV}$ Distance", fontsize=30)

plt.plot(bestfit[:,0], bestfit[:,1], "k", zorder=2)
plt.scatter(blue, logEW, zorder=1)
plt.xlabel("CIV Blueshift (km s$^{-1}$)", fontsize=20)
plt.ylabel("log(CIV EW [Å])", fontsize=20)
#plt.xlim(-650,4400)
plt.ylim(0.9,2.55)

plt.show()

# %% [markdown]
# Want the errors from EW+Blueshift to contribute equally.
#
# There are 3 sources of error we want to consider:
#
# *  Measurement error in EW
# *  Measurement error in blueshift
# *  Error connected to the distance from the curve.  Basically the further we are from the curve, the more likely measurement error in the former two points will land us at a different location along the curve.
#
# All of these are components of the question: Given the location in EW-blueshift space, and the perpendicular distance from the best-fit curve, what are the chances of it being projected onto another point along the curve?
#
# We don't have individual measurement errors, so I'll approximate $\sigma$ as the standard deviation in bins of EW/blueshift.

# %%
data   = np.array([blue, logEW]).T
scaler = joblib.load("../scalers/scaler_logEW.save")
data   = scaler.transform(data)
fit    = scaler.transform(bestfit)

# %%
blue_scale  = data[:,0]
logEW_scale = data[:,1]

# %%
fig = plt.figure(figsize=(9,9))

plt.plot(fit[:,0], fit[:,1], "k", zorder=2)
plt.scatter(blue_scale, logEW_scale, alpha=0.5, zorder=1)
plt.xlabel("CIV Blueshift (scaled)", fontsize=20)
plt.ylabel("log(CIV EW [scaled])", fontsize=20)
#plt.xlim(-650,4400)
#plt.ylim(0.9,2.55)
plt.gca().set_aspect("equal")
plt.show()

# %%
CIV_full = np.array([blue_scale, logEW_scale, dist]).T
CIV_full
# Out:
# array([[0.09294073, 0.42439028, 0.446845  ],
#        [0.35088371, 0.27549161, 0.69598032],
#        [0.23404955, 0.29254811, 0.59577144],
#        ...,
#        [0.27724345, 0.40973939, 0.55181405],
#        [0.25941345, 0.36412533, 0.56909928],
#        [0.21027892, 0.4778928 , 0.41635214]])

# %%
 n, bins, patches = plt.hist(dist, bins="scott")

# %%
fig, [ax1,ax2] = plt.subplots(1, 2, figsize=(16,6))
nEW, binsEW, patchesEW = ax1.hist(logEW_scale, bins="scott")#, bins=bins)
nBlue, binsBlue, patchesBlue = ax2.hist(blue_scale, bins="scott")
ax1.set_xlabel("Scaled logEW")
ax2.set_xlabel("Scaled Blueshift")
plt.show()

# %%
fig, [ax1,ax2] = plt.subplots(1, 2, figsize=(16,6))
left = 0
delta = 0.15
while True:
    if left >= 1.15:
        cond = (dist >= left)
        ax1.hist(logEW_scale[cond], bins=binsEW)#, bins=bins)
        ax2.hist(blue_scale[cond], bins=binsBlue)
        break
    right = left + delta
    cond  = ( (dist>=left) & (dist<right) )
    ax1.hist(logEW_scale[cond], bins=binsEW)#, bins=bins)
    ax2.hist(blue_scale[cond], bins=binsBlue)
    left += delta
ax1.set_xlabel("Scaled logEW")
ax2.set_xlabel("Scaled Blueshift")
plt.show()

# %% [markdown]
# Now plot the density just to compare shapes in separate bins.

# %%
fig, [ax1,ax2] = plt.subplots(1, 2, figsize=(16,6))
left = 0
delta = 0.15
while True:
    if left >= 1.15:
        cond = (dist >= left)
        ax1.hist(logEW_scale[cond], bins=binsEW, alpha=0.5, density=True)#, bins=bins)
        ax2.hist(blue_scale[cond], bins=binsBlue, alpha=0.5, density=True)
        break
    right = left + delta
    cond  = ( (dist>=left) & (dist<right) )
    ax1.hist(logEW_scale[cond], bins=binsEW, alpha=0.5, density=True)#, bins=bins)
    ax2.hist(blue_scale[cond], bins=binsBlue, alpha=0.5, density=True)
    left += delta
ax1.invert_xaxis()
ax1.set_xlabel("Scaled logEW")
ax2.set_xlabel("Scaled Blueshift")
plt.show()

# %% [markdown]
# These distributions are ugly, but make sense

# %% [markdown]
# Note: points beyond an endpoint of the curve will be projected onto the respective endpoint.

# %%
from time import time

start = time()
data = np.array([blue, logEW]).T
dist = CIV_distance(data, bestfit) #compute CIV distances like this
end = time()

# %%
fig = plt.figure(figsize=(7,7))
plt.hist(dist, bins="scott")
plt.ylabel("Number of Quasars", fontsize=15)
plt.xlabel("CIV Distance (Scaled Units)", fontsize=15)
plt.show()

# %% [markdown]
# ---
#
# #### Save time with the ``step`` parameter
#
# ``CIV_distance()`` function has an optional "step" parameter.  How it's normally set up is to project each data point onto the best-fit curve, then travel along the best-fit line--point-by-point--checking when you've passed a point on the line.  The default argument ``step=1`` will check every point along the curve, ``step=100`` will check every hundredth point etc.  Since the curve is so dense, you can often get away with a much higher step size than 1, decreasing your runtime dramatically (especially on bigger datasets); for example, ``step=100`` will result in 100 times less iterations of the for loop inside ``CIV_distance()``.
#
# Visualize accuracy as a function of step size.  Will consider "correct" to be the distances corresponding to ``step=1``.

# %%
bestfit.shape
# Out:
# (52920, 2)

# %%
step_list = np.logspace(np.log10(1), np.log10(2000), 11).astype(int)
diff_list = [0]
dt_list   = [end - start]
step_list
# Out:
# array([   1,    2,    4,    9,   20,   44,   95,  204,  437,  935, 2000])

# %%
for step_size in step_list[1:]:
    start_time = time()
    idist = CIV_distance(data, bestfit, step=step_size)
    diff_list.append(np.median(np.abs((dist-idist)/dist)))
    end_time = time()
    dt_list.append(end_time - start_time)

# %%
fig, ax1 = plt.subplots(figsize=(9,9))

color_frac = 'tab:red'
color_time = 'tab:blue'

ax1.set_xlabel('Step size', fontsize=20)
ax1.set_ylabel('runtime (seconds)', color=color_time, fontsize=20)
ax1.plot(step_list, dt_list, color=color_time)
ax1.tick_params(axis='y', labelcolor=color_time)
ax1.set_xlim(None, 1000)
ax1.set_ylim(0, None)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

ax2.set_ylabel('fractional error', color=color_frac, fontsize=20)  # we already handled the x-label with ax1
ax2.plot(step_list, diff_list, color=color_frac)
ax2.tick_params(axis='y', labelcolor=color_frac)
ax2.set_xlim(-15, 1000)
ax2.set_ylim(0, .034)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

fig, ax11 = plt.subplots(figsize=(9,9))

ax11.set_xlabel('Step size', fontsize=20)
ax11.set_ylabel('runtime (seconds)', color=color_time, fontsize=20)
ax11.plot(step_list, dt_list, color=color_time)
ax11.tick_params(axis='y', labelcolor=color_time)
ax11.set_xlim(None, 400)
ax11.set_ylim(0,5)

ax22 = ax11.twinx()  # instantiate a second axes that shares the same x-axis

ax22.set_ylabel('fractional error', color=color_frac, fontsize=20)  # we already handled the x-label with ax1
ax22.plot(step_list, diff_list, color=color_frac)
ax22.tick_params(axis='y', labelcolor=color_frac)
ax22.set_xlim(-15, 400)
ax22.set_ylim(0, 0.015)


fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %% [markdown]
# Plot showing both the time saved and median error in C IV distance as a function of step size.  Lesson learned: use a non-unity step size for lots of data! Roughly ``step=50-100`` looks like a good choice.  **Use the step parameter when testing big datasets.**
